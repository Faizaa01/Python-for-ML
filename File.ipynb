# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizaa01/Python-for-ML/blob/main/File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("./sample_data/sample.txt","r")

content = file.read()
print(content)
print(type(content))
file.close()
print(file.closed)
# Out:
# Hello World
# Welcome to Hell
#
# <class 'str'>
# True

# %%
file = open("./sample_data/sample.txt","r")

content = file.readlines()
print(content)
print(type(content))
print(file.closed)
file.close()
print(file.closed)
# Out:
# ['Hello World\n', 'Welcome to Hell\n']
# <class 'list'>
# False
# True

# %%
with open("./sample_data/sample.txt","r") as file:
  content = file.readlines()
  print(content)

print(file.closed)
# Out:
# ['Hello World\n', 'Welcome to Hell\n']
# True

# %%
with open("./sample_data/sample.txt","r") as file:
  content = file.readlines()
  content = list(map(str.strip, content))
  print(content)
  filtered_content = list(filter(lambda x: len(x)>0, content))
  print(filtered_content)
# Out:
# ['Hello World', 'Welcome to Hell', '']
# ['Hello World', 'Welcome to Hell']

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    # print(line,end="")
    l=line.strip()
    print(l)
# Out:
# Hello World
# Welcome to Hell

# %%
with open("./sample_data/test.txt","w") as file:
  file.write("Hello test file\n")
  file.write("How is it going?")

# %%
with open("./sample_data/test.txt","w") as file:
  file.write("Second Attempt\n")
  file.write("Is it still going on?\n")

# %%
with open("./sample_data/test.txt","a") as file:
  file.write("This is it\n")
  file.write("We come as one, wooo\n")

# %%
strings = ['go','leave','hell']
with open("./sample_data/test.txt","a") as file:
  file.writelines(strings)

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell())
  print(file.read(12))
  print(file.tell())
  print(file.read())
  print(file.tell())
# Out:
# 0
# Hello World
#
# 13
# Welcome to Hell
#
# 31

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell())
  print(file.read(12))
  print(file.seek(6))
  print(file.read())
# Out:
# 0
# Hello World
#
# 6
# World
# Welcome to Hell

# %%
with open("./sample_data/sample.txt","a") as file:
  file.write("Is this era beneficial?\n")
  file.write("It is too overwhelming!!")

# %%
from functools import reduce
with open("./sample_data/sample.txt","r") as file:
  strings = file.readlines()
  total_lines = len(strings)
  number_of_words = list(map(lambda x: len(x.split()), strings))
  total_words = reduce(lambda x,y:x+y, number_of_words)
  #remove newline
  string = list(map(str.strip, strings))
  #delete space
  string = list(map(lambda x: x.replace(" ",""), string))

  character_list = list(map(lambda x: len(x), string))
  total_character = reduce(lambda x,y:x+y, character_list)

with open("./sample_data/counter_of_sample.txt","w") as file:
  file.write(f"Total_line: {total_lines}\nTotal Number of Words: {total_words}\nTotal Characters: {total_character}\n")

# %%
with open("./sample_data/write_read.data","w+") as file:
  file.write("Hwloo woorldsss")
  file.seek(0)
  print(file.read())
  file.truncate(12)
  file.seek(0)
  print(file.read())
# Out:
# Hwloo woorldsss
# Hwloo woorld

# %% [markdown]
# Create a text file named emails.txt containing multiple email addresses, some in uppercase and some repeated.
# Write a Python program to clean the data by converting all emails to lowercase, removing duplicates, sorting them alphabetically, and saving the cleaned list to a new file named unique_emails.txt.

# %%
with open("./sample_data/email.txt","r") as file:
  s = file.readlines()
  ss = list(map(str.strip, s))
  ss = list(map(str.lower, ss))
  ss = list(set(ss))
  ss.sort()
  with open("./sample_data/unique_email.txt","w") as file:
    file.writelines(email + "\n" for email in ss)

# %% [markdown]
# Create a text file named names.txt containing a list of names.
# Some names may have extra spaces, inconsistent capitalization (like “aLiCe” or “ bob ”), or appear more than once.
# Write a Python program to clean the data by:
# 1.  Removing extra spaces.
# 2.  Converting all names so that only the first letter is capitalized.
# 3.  Removing duplicate names.
# 4. Sorting the names alphabetically.
# Finally, save the cleaned list into a new file named clean_names.txt.

# %%
with open("./sample_data/names.txt","r") as file:
  s = file.readlines()
  s = list(map(str.strip,s))
  s = [x.title().strip() for x in s if x.strip()]
  s = sorted(set(s))
  print(s)
# Out:
# ['Alice', 'Anjana Niha', 'Baekhyun', 'Bob', 'Kai', 'Kim Teahyang', 'Suho']

# %% [markdown]
# Write a Python program that creates a list of 5 numbers.
# Ask the user for an index number and print the value at that index.
# If the index is out of range, handle the exception and print "Invalid index!".

# %%
arr = [1,2,3,4,5]
n=int(input())
try:
  print(arr[n])
except IndexError:
  print("Invalid index")
# Out:
# 2
# 3

# %%
s =[1,2,3,4,5]
s.insert(0,33)
print(s)
# Out:
# [33, 1, 2, 3, 4, 5]

# %%
s = "helloo i am your hellish predator"

ss= list(map(str.upper , s))
ss = "".join(ss)
print(ss)
# Out:
# HELLOO I AM YOUR HELLISH PREDATOR
